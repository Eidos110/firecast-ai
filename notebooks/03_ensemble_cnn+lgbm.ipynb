# %%
# 1. Do Ensemble method = CNN + LightGBM

import pandas as pd
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import roc_auc_score, classification_report, precision_recall_curve
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')
import lightgbm as lgb

# ----------------------------
# 1. Load & Prepare Data (with lag3/roll7)
# ----------------------------
dfv1 = pd.read_csv('../data/processed_firecast_features_v3.csv')



# Features and labels
X = dfv1.drop(['label', 'time'], axis=1)
y = dfv1['label']

# Temporal 90/10 split
split_idx = int(0.9 * len(dfv1))
X_train, X_test = X.iloc[:split_idx], X.iloc[split_idx:]
y_train, y_test = y.iloc[:split_idx], y.iloc[split_idx:]

# Scale features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# ----------------------------
# 2. Dataset & CNN Model (same as your best)
# ----------------------------
class WildfireDataset(Dataset):
    def __init__(self, features, labels):
        self.X = features
        self.y = labels.values

    def __len__(self):
        return len(self.X)

    def __getitem__(self, i):
        return torch.tensor(self.X[i], dtype=torch.float32), torch.tensor(self.y[i], dtype=torch.float32)

class OptimizedCNN1D(nn.Module):
    def __init__(self, input_dim, dropout_rate=0.3):
        super(OptimizedCNN1D, self).__init__()
        self.conv_block1 = nn.Sequential(
            nn.Conv1d(1, 32, 3, padding=1), nn.BatchNorm1d(32), nn.ReLU(),
            nn.Conv1d(32, 32, 3, padding=1), nn.BatchNorm1d(32), nn.ReLU(),
            nn.MaxPool1d(2), nn.Dropout(dropout_rate)
        )
        self.conv_block2 = nn.Sequential(
            nn.Conv1d(32, 64, 3, padding=1), nn.BatchNorm1d(64), nn.ReLU(),
            nn.Conv1d(64, 64, 3, padding=1), nn.BatchNorm1d(64), nn.ReLU(),
            nn.MaxPool1d(2), nn.Dropout(dropout_rate)
        )
        self.conv_block3 = nn.Sequential(
            nn.Conv1d(64, 128, 3, padding=1), nn.BatchNorm1d(128), nn.ReLU(),
            nn.AdaptiveAvgPool1d(4), nn.Dropout(dropout_rate)
        )
        with torch.no_grad():
            dummy = torch.zeros(1, 1, input_dim)
            out = self.conv_block3(self.conv_block2(self.conv_block1(dummy)))
            self.flattened_size = out.view(1, -1).size(1)
        self.dense = nn.Sequential(
            nn.Linear(self.flattened_size, 256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(dropout_rate),
            nn.Linear(256, 128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(dropout_rate)
        )
        self.output = nn.Linear(128, 1)

    def forward(self, x):
        x = x.unsqueeze(1)
        x = self.conv_block1(x)
        x = self.conv_block2(x)
        x = self.conv_block3(x)
        x = x.view(x.size(0), -1)
        x = self.dense(x)
        return self.output(x).squeeze(1)

# --- Training Function ---
def train_model(model, train_loader, val_loader, epochs=150, lr=0.001):
    device = next(model.parameters()).device
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=1e-3)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(
        optimizer, max_lr=lr, epochs=epochs, steps_per_epoch=len(train_loader)
    )
    criterion = nn.BCEWithLogitsLoss()  # Works with raw logits

    best_auc = 0
    patience, counter = 15, 0

    for epoch in range(epochs):
        model.train()
        total_loss = 0
        for x, y in train_loader:
            x, y = x.to(device), y.to(device)
            optimizer.zero_grad()
            logits = model(x)
            loss = criterion(logits, y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            scheduler.step()
            total_loss += loss.item()

        # Validation
        model.eval()
        val_logits, val_labels = [], []
        with torch.no_grad():
            for x, y in val_loader:
                x, y = x.to(device), y.to(device)
                logits = model(x)
                val_logits.extend(logits.cpu().numpy())
                val_labels.extend(y.cpu().numpy())

        val_probs = torch.sigmoid(torch.tensor(val_logits)).numpy()
        if len(set(val_labels)) > 1:
            val_auc = roc_auc_score(val_labels, val_probs)
        else:
            val_auc = 0.0

        if val_auc > best_auc:
            best_auc = val_auc
            torch.save(model.state_dict(), "best_cnn1d_timeaware.pth")
            counter = 0
        else:
            counter += 1
            if counter >= patience:
                print(f"Early stopping at epoch {epoch+1}")
                break

        if (epoch + 1) % 20 == 0 or epoch == 0:
            print(f"Epoch {epoch+1} | Loss: {total_loss/len(train_loader):.4f} | Val AUC: {val_auc:.4f}")

    print(f"✅ Training finished. Best Val AUC: {best_auc:.4f}")
    return best_auc


# ----------------------------
# 3. Train CNN
# ----------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

train_dataset = WildfireDataset(X_train_scaled, y_train)
val_dataset = WildfireDataset(X_test_scaled, y_test)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

print(f"Training on device: {device}")

cnn_model = OptimizedCNN1D(input_dim=X_train_scaled.shape[1], dropout_rate=0.3).to(device)
train_model(cnn_model, train_loader, val_loader, epochs=150, lr=0.001)

# Get CNN predictions
cnn_model.eval()
cnn_probs = []
with torch.no_grad():
    for x, _ in val_loader:
        x = x.to(device)
        logits = cnn_model(x)
        probs = torch.sigmoid(logits).cpu().numpy()
        cnn_probs.extend(probs)
cnn_probs = np.array(cnn_probs)

#----------------------------
# 4. Train LightGBM
# ----------------------------
print("Training LightGBM...")
params_1 = {
    'objective': 'binary',
    'metric': 'auc',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'learning_rate': 0.05,
    'feature_fraction': 0.9,
    'bagging_fraction': 0.8,
    'bagging_freq': 5,
    'verbose': -1,
    'is_unbalance': True  # Handle class imbalance
}

train_data = lgb.Dataset(X_train_scaled, label=y_train)
valid_data = lgb.Dataset(X_test_scaled, label=y_test, reference=train_data)

lgbm_model = lgb.train(params_1, train_data, valid_sets=[valid_data], num_boost_round=1000)

# Booster.predict(...) returns the predicted probability for binary objective.
lgbm_probs = lgbm_model.predict(X_test_scaled)

# ----------------------------
# 5. Ensemble & Evaluate
# ----------------------------
# Simple average ensemble
#ensemble_probs = (cnn_probs + lgbm_probs) / 2
ensemble_probs = 0.45 * cnn_probs +  0.55 * lgbm_probs

# Find threshold for 80% fire recall
def find_threshold_for_recall(y_true, y_prob, target_recall=0.80):
    precision, recall, thresholds = precision_recall_curve(y_true, y_prob)
    idx = np.where(recall >= target_recall)[0]
    if len(idx) == 0:
        return 0.5
    best_idx = idx[np.argmax(precision[idx])]
    return thresholds[best_idx]

final_thresh = find_threshold_for_recall(y_test.values, ensemble_probs, target_recall=0.80)
ensemble_preds = (ensemble_probs > final_thresh).astype(int)

# ----------------------------
# 6. Final Results
# ----------------------------
print("\n" + "="*60)
print("ENSEMBLE MODEL RESULTS (CNN + LGBM)")
print("="*60)
print(f"AUC: {roc_auc_score(y_test, ensemble_probs):.4f}")
print(f"Optimal threshold for 80% fire recall: {final_thresh:.3f}")
print("\nClassification Report:")
print(classification_report(y_test, ensemble_preds, target_names=['No Fire', 'Fire']))

# Save models (optional)
import joblib
#torch.save(cnn_model.state_dict(), "cnn_best.pth")
#joblib.dump(xgb_model, "xgb_best.pkl")
#joblib.dump(scaler, "scaler.pkl")
# Out:
# Training on device: cuda
# Epoch 1 | Loss: 0.6962 | Val AUC: 0.7045
# Epoch 20 | Loss: 0.5509 | Val AUC: 0.8725
# Epoch 40 | Loss: 0.5249 | Val AUC: 0.8768
# Epoch 60 | Loss: 0.5055 | Val AUC: 0.8776
# Early stopping at epoch 63
# ✅ Training finished. Best Val AUC: 0.8802
# Training LightGBM...
#
# ============================================================
# ENSEMBLE MODEL RESULTS (CNN + LGBM)
# ============================================================
# AUC: 0.8878
# Optimal threshold for 80% fire recall: 0.435
#
# Classification Report:
#               precision    recall  f1-score   support
#
#      No Fire       0.76      0.83      0.79      2447
#         Fire       0.86      0.80      0.83      3175
#
#     accuracy                           0.81      5622
#    macro avg       0.81      0.81      0.81      5622
# weighted avg       0.82      0.81      0.81      5622
